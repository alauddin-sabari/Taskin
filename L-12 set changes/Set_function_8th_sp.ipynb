# %% [markdown]
# ## Union of two sets

# %%
 {1,3,4}.union({3,4,5})
# by law  we know that set doesn't duplicate values
# Out:
# {1, 3, 4, 5}

# %%
set1 = {'TASKIN', 'zabir','zahin'}
set2 = {'sam','aven','loid' }

# %%
def link(set1,set2):
    linked=set1 .union(set2)
    print(linked)
    return linked

# %%
link(set1,set2)
# Out:
# {'loid', 'zabir', 'aven', 'TASKIN', 'zahin', 'sam'}
# {'TASKIN', 'aven', 'loid', 'sam', 'zabir', 'zahin'}

# %%
x = link(set1,set2)
# Out:
# {'loid', 'zabir', 'aven', 'TASKIN', 'zahin', 'sam'}

# %%
x
# Out:
# {'TASKIN', 'aven', 'loid', 'sam', 'zabir', 'zahin'}

# %%
total_friends = link

# %% [markdown]
# Set Intersction ( common features returning)

# %% [markdown]
# ![image.png](attachment:fb9f2850-c71f-4c14-82f9-031f5a965b8a.png)

# %%
{1,2,3 }.intersection({2,3,4,5})
# Out:
# {2, 3}

# %% [markdown]
# find the list of friends who have their common food choice

# %%
your_food={'pizza','chips','fries','chicken','chop','egg'}
friends_food={'pizza','chips','fish','egg','fried chicken','soup'}
def intersect (your_food,friends_food):
    some=your_food.intersection(friends_food)
    print (some)
    return some

inter=intersect(your_food,friends_food)
# Out:
# {'pizza', 'chips', 'egg'}

# %%
intersect(your_food,friends_food)
# Out:
# {'pizza', 'chips', 'egg'}
# {'chips', 'egg', 'pizza'}

# %%
inter
# Out:
# {'chips', 'egg', 'pizza'}
